# %%
result_list = []
number = 0
for i in range(1,21):
  if i % 3 == 0:
    number = "Multiple",i

    result_list.append(number)
  else:
    number = i
    result_list.append(number)

print(result_list)
# Out:
# [1, 2, ('Multiple', 3), 4, 5, ('Multiple', 6), 7, 8, ('Multiple', 9), 10, 11, ('Multiple', 12), 13, 14, ('Multiple', 15), 16, 17, ('Multiple', 18), 19, 20]
